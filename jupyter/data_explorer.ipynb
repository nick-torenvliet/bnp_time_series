# %%
import pandas as pd
# %matplotlib inline

# %%
anomaly_df = pd.read_csv("./data/anomaly.csv", index_col=0)
group_df = pd.read_csv("./data/groups.csv", index_col=0)
# Out:
# /home/torenvln/git/interpreters/p27/local/lib/python2.7/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
anomaly_df.plot()

# %%
group_df.plot()

# %%
anomaly_df.head()
# Out:
#      anomaly
# 0  25.505474
# 1  25.582708
# 2  25.540054
# 3  25.521753
# 4  25.600965

# %%
group_df.head()
# Out:
#    group_1.0  group_1.1  group_1.2  group_2.0  group_2.1  group_2.2  \
# 0   62.46778  62.556137  62.445694  62.224842  61.827423  62.578228
# 1   62.46778  62.556137  62.445694  62.224842  61.827423  62.578228
# 2   62.31318  62.224842  62.511960  61.981956  61.959880  62.777058
# 3   62.46778  62.511960  62.401520  62.048195  61.783270  62.511960
# 4   62.40152  62.556137  62.357350  62.180680  61.893650  62.578228
#
#    group_2.3  group_3.0  group_3.1  group_3.2  group_4.0  group_4.1  group_4.2
# 0  62.666590  253.05576  252.95404  253.03033  63.285343  59.512016  43.874710
# 1  62.666590  253.05576  252.95404  253.03033  63.285343  59.512016  43.874710
# 2  62.578228  253.00490  252.87775  252.95404  62.953823  59.644196  44.026722
# 3  62.136513  253.05576  252.92860  253.03033  59.666225  63.484300  40.990547
# 4  62.445694  253.05576  252.92860  253.03033  61.981956  58.433178  46.548832
