# %% [markdown]
# # Data Explorer
# This file shows detail regarding the data format required to use custom data sets with the example applications included in the __bnp_time_series__ repository.
#
# If data in a comma separated value (csv) file is arranged so that the first row contains headers that provide labels for the data in each of the columns, and the first column consists of an index to your data on the integers $0,...,n$ e.g. in a format matching the data files in the __data__ directory of this repository, it should work with the example application code provided in this repository.

# %%
# Import the required python libraries imported
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# Indicates to jupyer how the plots are to be displayed and sized
# %matplotlib inline
plt.rcParams['figure.figsize'] = [15, 10]

# %%
# Read in the data
anomaly_df = pd.read_csv("../data/data.csv", index_col=0)
group_df = pd.read_csv("../data/grp2.csv", index_col=0)

# %%
# Plot the data
anomaly_df.plot()

# %%
# Plot the data
group_df.plot()

# %%
# Check data structure
anomaly_df.head()
# Out:
#      anomaly
# 0  45.605164
# 1  45.692140
# 2  45.637207
# 3  45.600586
# 4  45.573120

# %%
# Check data structure
group_df.head()
# Out:
#    group_2.0  group_2.1  group_2.2  group_2.3
# 0  62.224842  61.827423  62.578228  62.666590
# 1  62.224842  61.827423  62.578228  62.666590
# 2  61.981956  61.959880  62.777058  62.578228
# 3  62.048195  61.783270  62.511960  62.136513
# 4  62.180680  61.893650  62.578228  62.445694
