# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from trcrpm import TRCRP_Mixture
from bokeh.plotting import figure, show
from bokeh.io import output_notebook, push_notebook
from bokeh.core.validation import silence
from bokeh.core.validation.warnings import MISSING_RENDERERS
from bokeh.layouts import column
from IPython.core.display import display, HTML
display(HTML("<style>div.output_scroll { height: 60em; }</style>"))
# %matplotlib inline
silence(MISSING_RENDERERS, True)
# Out:
# <style>div.output_scroll { height: 60em; }</style>
# {1000}

# %%
anomaly = pd.read_csv("./data/anomaly.csv", index_col=0)

# %%
anomaly.plot()

# %%
output_notebook()
chain = 0
                         
p1 = figure(title=anomaly.columns[0], plot_height=350, plot_width=800)
p2 = figure(title="CRP States", plot_height=350, plot_width=800, x_range=p1.x_range)
p = column(p1, p2)
target = show(p, notebook_handle=True)

x, eng_val, states, num_states = [], [], [], []
i = 0
step = 500
print(i)
rng = np.random.RandomState(1)
model = TRCRP_Mixture(chains=4, lag=10, variables=anomaly.columns, rng=rng)
model.incorporate(anomaly[i:i + step])
model.resample_all(seconds=10)
model.resample_hyperparameters(seconds=10)
s = model.get_temporal_regimes('anomaly')[chain]
num_states = step * [len(sorted(set(s)))]
states = list(s[i:i + step])
eng_val = anomaly.iloc[i:i + step, 0].tolist()
x = list(range(i, i + step ))

for i in range(step, len(anomaly) - step, step):
    print(i)
    line1 = p1.line(x = x,
                   y = eng_val,
                   color='blue',
                   name='g1',
                   line_width=1)

    line2 = p2.line(x = x,
                   y = num_states,
                   color='red',
                   name='g2',
                   line_width=1)

    line3 = p2.line(x = x,
                   y = states,
                   color='green',
                   name='g3',
                   line_width=1)

    push_notebook(handle=target)   
    model.incorporate(anomaly[i:i + step])
    model.resample_all(seconds=10)
    model.resample_hyperparameters(seconds=10)
    s = model.get_temporal_regimes("anomaly")[chain]
    num_states = step * [len(sorted(set(s)))]
    states = list(s[i:i + step])
    eng_val = anomaly.iloc[i:i + step, 0].tolist()
    x = list(range(i, i + step ))
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1473">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="2262844b-227e-483f-bb76-1fbbf08e4f70" data-root-id="1541"></div>
# 0
# Completed: 74 iterations in 10.006392 seconds.
# Completed: 102 iterations in 10.039508 seconds.
# Completed: 98 iterations in 10.060006 seconds.
# Completed: 102 iterations in 10.097651 seconds.
# Completed: 15 iterations in 10.307094 seconds.
# Completed: 15 iterations in 10.367037 seconds.
# Completed: 13 iterations in 10.521349 seconds.
# Completed: 12 iterations in 10.533360 seconds.
# 500
# Completed: 42 iterations in 10.001123 seconds.
# Completed: 40 iterations in 10.031476 seconds.
# Completed: 33 iterations in 10.084282 seconds.
# Completed: 38 iterations in 10.203799 seconds.
# Completed: 17 iterations in 10.040726 seconds.
# Completed: 16 iterations in 10.435357 seconds.
# Completed: 12 iterations in 10.667408 seconds.
# Completed: 11 iterations in 10.781713 seconds.
# 1000
# Completed: 33 iterations in 10.020023 seconds.
# Completed: 23 iterations in 10.085934 seconds.
# Completed: 23 iterations in 10.115285 seconds.
# Completed: 35 iterations in 10.145593 seconds.
# Completed: 13 iterations in 10.023123 seconds.
# Completed: 9 iterations in 10.232643 seconds.
# Completed: 22 iterations in 10.346570 seconds.
# Completed: 16 iterations in 10.468808 seconds.
# 1500
# Completed: 20 iterations in 10.037951 seconds.
# Completed: 25 iterations in 10.049798 seconds.
# Completed: 24 iterations in 10.122999 seconds.
# Process Process-280:
# Process Process-278:
#     self.run()
#   File "/home/torenvln/git/interpreters/p27/local/lib/python2.7/site-packages/cgpm/utils/parallel_map.py", line 45, in process_input
# Process Process-286:
# Process Process-284:
# Process Process-277:
# Process Process-285:
# Process Process-281:
# Process Process-288:
# Process Process-287:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process Process-282:
# Process Process-283:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     self.run()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-9b82f9bbeb11> in <module>()
#      44     push_notebook(handle=target)
#      45     model.incorporate(anomaly[i:i + step])
# ---> 46     model.resample_all(seconds=10)
#      47     model.resample_hyperparameters(seconds=10)
#      48     s = model.get_temporal_regimes("anomaly")[chain]
#
# /home/torenvln/git/interpreters/p27/local/lib/python2.7/site-packages/trcrpm/trcrpm.pyc in resample_all(self, steps, seconds)
#     106         until the given number of seconds elapse, whichever comes first.
#     107         """
# --> 108         self._transition(N=steps, S=seconds, backend='lovecat')
#     109
#     110     def resample_hyperparameters(self, steps=None, seconds=None, variables=None):
#
# /home/torenvln/git/interpreters/p27/local/lib/python2.7/site-packages/trcrpm/trcrpm.pyc in _transition(self, **kwargs)
#     276             self.engine.transition(**kwargs)
#     277         elif backend in ['lovecat']:
# --> 278             self.engine.transition_lovecat(**kwargs)
#     279         elif backend in ['loom']:
#     280             self.engine.transition_loom(**kwargs)
#
# /home/torenvln/git/interpreters/p27/local/lib/python2.7/site-packages/cgpm/crosscat/engine.pyc in transition_lovecat(self, N, S, kernels, rowids, cols, progress, checkpoint, statenos, multiprocess)
#      94                 (N, S, kernels, rowids, cols, progress, checkpoint))
#      95                 for s in statenos]
# ---> 96         states = mapper(_modify, args)
#      97         for s, state in zip(statenos, states):
#      98             self.states[s] = state
#
# /home/torenvln/git/interpreters/p27/local/lib/python2.7/site-packages/cgpm/utils/parallel_map.pyc in parallel_map(f, l, parallelism)
#      96         # Process all the remaining output items.
#      97         while 0 < ctr[0]:
# ---> 98             j = le32dec(os.read(retq_rd, 4))
#      99             process_output(fl, ctr, outq[j][0].recv())
#     100
#
# KeyboardInterrupt:
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     self.run()
#     self.run()
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self.run()
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self.run()
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#     self.run()
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#   File "/home/torenvln/git/interpreters/p27/local/lib/python2.7/site-packages/cgpm/utils/parallel_map.py", line 45, in process_input
#     self._target(*self._args, **self._kwargs)
#   File "/home/torenvln/git/interpreters/p27/local/lib/python2.7/site-packages/cgpm/utils/parallel_map.py", line 45, in process_input
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/torenvln/git/interpreters/p27/local/lib/python2.7/site-packages/cgpm/utils/parallel_map.py", line 45, in process_input
#     i = inq_rd.recv()
#     self._target(*self._args, **self._kwargs)
#   File "/home/torenvln/git/interpreters/p27/local/lib/python2.7/site-packages/cgpm/utils/parallel_map.py", line 45, in process_input
#     i = inq_rd.recv()
#     self._target(*self._args, **self._kwargs)
#   File "/home/torenvln/git/interpreters/p27/local/lib/python2.7/site-packages/cgpm/utils/parallel_map.py", line 45, in process_input
#   File "/home/torenvln/git/interpreters/p27/local/lib/python2.7/site-packages/cgpm/utils/parallel_map.py", line 45, in process_input
#     self._target(*self._args, **self._kwargs)
#     i = inq_rd.recv()
# KeyboardInterrupt
#     i = inq_rd.recv()
#   File "/home/torenvln/git/interpreters/p27/local/lib/python2.7/site-packages/cgpm/utils/parallel_map.py", line 45, in process_input
# KeyboardInterrupt
#     i = inq_rd.recv()
#     i = inq_rd.recv()
# KeyboardInterrupt
#   File "/home/torenvln/git/interpreters/p27/local/lib/python2.7/site-packages/cgpm/utils/parallel_map.py", line 45, in process_input
# KeyboardInterrupt
#     i = inq_rd.recv()
#   File "/home/torenvln/git/interpreters/p27/local/lib/python2.7/site-packages/cgpm/utils/parallel_map.py", line 45, in process_input
#     i = inq_rd.recv()
#     i = inq_rd.recv()
#   File "/home/torenvln/git/interpreters/p27/local/lib/python2.7/site-packages/cgpm/utils/parallel_map.py", line 45, in process_input
# KeyboardInterrupt
#     i = inq_rd.recv()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#     i = inq_rd.recv()
# KeyboardInterrupt

# %%
probes = model.dataset.index
numsamples = 20
samples = model.simulate(probes, model.variables, numsamples)

# %%
def plot_latent_state_sequence(timesteps, values, states, ax):
    assert len(timesteps) == len(states)
    unique = sorted(set(states))
    colors = matplotlib.cm.Set1(np.linspace(0, 1, len(unique)))
    y_low, y_high = ax.get_ylim()
    y_mid = np.mean([y_low, y_high])
    y_height = 0.05 * (y_high - y_low)
    for state, color in zip(unique, colors):
        xs = timesteps[states==state]
        for x in xs:
            ax.fill_between([x-1, x], [y_mid-y_height]*2, [y_mid+y_height]*2,
                alpha=0.3, color=color)

# %%
def plot_predictions(simulations, variable, ax, states_from_chain=None):
    index = model.variables.index(variable)
    # Plot the observed data.
    x_observed = model.dataset.index
    y_observed = model.dataset.loc[:,variable]
    ax.plot(x_observed, y_observed, label=variable, color='k', linewidth=1)
    # Plot 25--75 percentile bands around the simulated data. 
    samples = simulations[:,:,index]
    ax.fill_between(
        probes,
        np.percentile(samples, 25, axis=0),
        np.percentile(samples, 75, axis=0),
        color='gray',
        alpha=0.5)
    #ax.set_ylim([min(y_observed)-2, max(y_observed)+2])
    #  Optionally plot latent temporal state at each timepoint,
    #  according to a given chain in the model.
    if states_from_chain is not None:
        assert 0 <= states_from_chain < model.chains
        states = model.get_temporal_regimes(variable)[states_from_chain]
        plot_latent_state_sequence(x_observed, y_observed, states, ax)
    # Add the legend.
    ax.legend(loc='upper left', handletextpad=0)

# %%
fig, axes = plt.subplots(nrows=1)
plot_predictions(samples, 'anomaly', axes)
axes.set_xlim([min(probes), max(probes)])
fig.set_size_inches(20,10)

# %%
chain = 0
samples_chain = samples[numsamples*chain:numsamples*(chain+1)]

# %%
fig, axes = plt.subplots(nrows=1)
plot_predictions(samples_chain, 'anomaly', axes, states_from_chain=chain)
axes.set_xlim([min(probes), max(probes)])
fig.set_size_inches(20,10)

# %%
probes = list(model.dataset.index) + range(max(model.dataset.index), max(model.dataset.index)+100)
numsamples = 20
samples = model.simulate(probes, model.variables, numsamples)

# %%
fig, axes = plt.subplots(nrows=1)
plot_predictions(samples, 'anomaly', axes)
axes.set_xlim([min(probes), max(probes)])
fig.set_size_inches(20,10)

# %%
# %qtconsole
