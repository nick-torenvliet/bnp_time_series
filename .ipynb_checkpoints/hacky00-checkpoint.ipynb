# %% [markdown]
# ## bnp_time_series Installation
#
# To install a virtuall environment for python refer to https://www.tensorflow.org/install/pip.
#
# Once your environment is activated:
# ```
# pip install jupyterlab
# pip install h5py
# pip install pandas
# pip install matplotlib
# ```

# %%
data_file = "./data/1xM_20190101_00.raw.hdf5"
f = h5py.File(data_file, 'r' ) 
tag_names = list(f.keys())

df_list = []

for tag in tag_names:
    ts = f.get(tag+"/time_stamp")
    ev = f.get(tag+"/eng_val")
    df = pd.DataFrame({'time_stamp':ts, tag: ev})
    df = df.round({'time_stamp':-3})
    df = df.set_index(['time_stamp'])
    df_list.append(df)
    
df = pd.concat(df_list, axis=1)
df = df.interpolate()

# %%
df.to_pickle("./df.pkl")

# %%
import h5py
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from trcrpm import TRCRP_Mixture
# %matplotlib inline

# %%
df = pd.read_pickle("./df.pkl")
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-a574c16d386c> in <module>()
# ----> 1 df = pd.read_pickle("./df.pkl")
#
# /usr/lib/python2.7/dist-packages/pandas/io/pickle.pyc in read_pickle(path)
#      58
#      59     try:
# ---> 60         return try_read(path)
#      61     except:
#      62         if PY3:
#
# /usr/lib/python2.7/dist-packages/pandas/io/pickle.pyc in try_read(path, encoding)
#      54             # compat pickle
#      55             except:
# ---> 56                 with open(path, 'rb') as fh:
#      57                     return pc.load(fh, encoding=encoding, compat=True)
#      58
#
# IOError: [Errno 2] No such file or directory: './df.pkl'

# %%
l = 850
r = 851
nr = r-l
x = 20
y = 20
n = 200
frame = df.iloc[0:n,l:r]
frame = frame.reset_index()
frame = frame.drop('time_stamp', 1)

# %%
plt.rcParams['figure.figsize'] = [x, y]
fig, axes = plt.subplots(nrows=nr)
for ax, variable in zip(axes, frame.columns):
    index = list(frame.columns).index(variable)
    x_observed = frame.index
    y_observed = frame.loc[:,variable]
    ax.plot(x_observed, y_observed, label=variable, color='k', linewidth=1)
    ax.legend(loc='upper left', handletextpad=0)
#fig.set_size_inches(5,20)

# %%
frame.plot()

# %%
rng = np.random.RandomState(1)
model = TRCRP_Mixture(chains=4, lag=10, variables=frame.columns, rng=rng)
model.incorporate(frame)

# %%
model.resample_all(seconds=20)
# Out:
# Completed: 277 iterations in 20.011477 seconds.
# Completed: 372 iterations in 20.011328 seconds.
# Completed: 171 iterations in 20.002526 seconds.
# Completed: 211 iterations in 20.089814 seconds.

# %%
model.resample_hyperparameters(seconds=10)
# Out:
# Completed: 5 iterations in 10.712893 seconds.
# Completed: 8 iterations in 11.014149 seconds.
# Completed: 4 iterations in 11.371551 seconds.
# Completed: 9 iterations in 11.551459 seconds.

# %%
probes = model.dataset.index
numsamples = 20
samples = model.simulate(probes, model.variables, numsamples)

# %%
def plot_latent_state_sequence(timesteps, values, states, ax):
    assert len(timesteps) == len(states)
    unique = sorted(set(states))
    colors = matplotlib.cm.Set1(np.linspace(0, 1, len(unique)))
    y_low, y_high = ax.get_ylim()
    y_mid = np.mean([y_low, y_high])
    y_height = 0.05 * (y_high - y_low)
    for state, color in zip(unique, colors):
        xs = timesteps[states==state]
        for x in xs:
            ax.fill_between([x-1, x], [y_mid-y_height]*2, [y_mid+y_height]*2,
                alpha=0.3, color=color)

# %%
def plot_predictions(simulations, variable, ax, states_from_chain=None):
    index = model.variables.index(variable)
    # Plot the observed data.
    x_observed = model.dataset.index
    y_observed = model.dataset.loc[:,variable]
    ax.plot(x_observed, y_observed, label=variable, color='k', linewidth=1)
    # Plot 25--75 percentile bands around the simulated data. 
    samples = simulations[:,:,index]
    ax.fill_between(
        probes,
        np.percentile(samples, 25, axis=0),
        np.percentile(samples, 75, axis=0),
        color='gray',
        alpha=0.5)
    ax.set_ylim([min(y_observed)-2, max(y_observed)+2])
    #  Optionally plot latent temporal state at each timepoint,
    #  according to a given chain in the model.
    if states_from_chain is not None:
        assert 0 <= states_from_chain < model.chains
        states = model.get_temporal_regimes(variable)[states_from_chain]
        plot_latent_state_sequence(x_observed, y_observed, states, ax)
    # Add the legend.
    ax.legend(loc='upper left', handletextpad=0)

# %%
fig, axes = plt.subplots(nrows=nr)
plt.rcParams['figure.figsize'] = [x, y]
for ax, variable in [axes, model.variables]:
    plot_predictions(samples, variable, ax)
    ax.set_xlim([min(probes), max(probes)])
#fig.set_size_inches(5,20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-0c5b486defec> in <module>()
#       1 fig, axes = plt.subplots(nrows=nr)
#       2 plt.rcParams['figure.figsize'] = [x, y]
# ----> 3 for ax, variable in [axes, model.variables]:
#       4     plot_predictions(samples, variable, ax)
#       5     ax.set_xlim([min(probes), max(probes)])
#
# TypeError: 'AxesSubplot' object is not iterable

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-7f3b2781088d> in <module>()
#       2 plt.rcParams['figure.figsize'] = [x, y]
#       3 #for ax, variable in zip(axes, model.variables):
# ----> 4 plot_predictions(samples, model.variables, axes)
#       5 ax.set_xlim([min(probes), max(probes)])
#       6 #fig.set_size_inches(5,20)
#
# <ipython-input-14-9a4afa50312c> in plot_predictions(simulations, variable, ax, states_from_chain)
#       1 def plot_predictions(simulations, variable, ax, states_from_chain=None):
# ----> 2     index = model.variables.index(variable)
#       3     # Plot the observed data.
#       4     x_observed = model.dataset.index
#       5     y_observed = model.dataset.loc[:,variable]
#
# ValueError: [u'1-63331-P1-TT12@ai3452'] is not in list

# %%
chain = 0
samples_chain = samples[numsamples*chain:numsamples*(chain+1)]

fig, axes = plt.subplots(nrows=nr)
plt.rcParams['figure.figsize'] = [x, y]
for ax, variable in zip(axes, model.variables):
    plot_predictions(samples_chain, variable, ax, states_from_chain=chain)
    ax.set_xlim([min(probes), max(probes)])
#fig.set_size_inches(10,10)

# %%
probes = list(model.dataset.index) + range(max(model.dataset.index), max(model.dataset.index)+100)
numsamples = 20
samples = model.simulate(probes, model.variables, numsamples)

# %%
fig, axes = plt.subplots(nrows=nr)
plt.rcParams['figure.figsize'] = [x, y]
for ax, variable in zip(axes, model.variables):
    plot_predictions(samples, variable, ax)
    ax.set_xlim([min(probes), max(probes)])
#fig.set_size_inches(5, 20)

# %%
# %qtconsole
